# %% [markdown]
# <div style="text-align: right">INFO 6106 Machine Learning Final Project</div>
# <div style="text-align: right">Dino Konstantopoulos 5 April 2025</div>

# %%
import pandas as pd
path = r'D:\user\docs\NU\_Noctis\2006Fall_2017Spring_GOES_meteo_combined.csv'
df = pd.read_csv(path, nrows= 100)
df
# Out:
#       Date_UTC Time_UTC    Date_CST Time_CST  \
# 0   2006-10-01    00:00  2006-09-30    00:00
# 1   2006-10-01    01:00  2006-09-30    01:00
# 2   2006-10-01    02:00  2006-09-30    02:00
# 3   2006-10-01    03:00  2006-09-30    03:00
# 4   2006-10-01    04:00  2006-09-30    04:00
# ..         ...      ...         ...      ...
# 95  2006-10-04    23:00  2006-10-04    23:00
# 96  2006-10-05    00:00  2006-10-04    00:00
# 97  2006-10-05    01:00  2006-10-04    01:00
# 98  2006-10-05    02:00  2006-10-04    02:00
# 99  2006-10-05    03:00  2006-10-04    03:00
#
#                         File_name_for_1D_lake  \
# 0   goes11.2006.10.01.0000.v01.nc-var1-t0.csv
# 1   goes11.2006.10.01.0100.v01.nc-var1-t0.csv
# 2   goes11.2006.10.01.0200.v01.nc-var1-t0.csv
# 3   goes11.2006.10.01.0300.v01.nc-var1-t0.csv
# 4   goes11.2006.10.01.0400.v01.nc-var1-t0.csv
# ..                                        ...
# 95  goes11.2006.10.04.2300.v01.nc-var1-t0.csv
# ...

# %%
df.to_csv(r'D:\user\docs\NU\_Noctis\2006Fall_2017Spring_GOES_meteo_combined_first-100-rows.csv')

# %% [markdown]
# Other options:

# %%
df = pd.read_csv(path, nrows= 20)
from dask import dataframe as dd

df= dd.read_csv(“filename”)

# %%
import sxl
from datetime import datetime
startTime = datetime.now()
wb = sxl.Workbook('\\Big_Excel.xlsx')
ws = wb.sheets[1]
data = ws.head(5)
print("Time taken to load top 5 rows using sxl is {}".format((datetime.now() - startTime)))
